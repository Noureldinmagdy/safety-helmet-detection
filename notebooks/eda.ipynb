# %%
# %cd ..

# %%
import yaml

# %%
with open("safety-helmet-1/data.yaml", "r") as f:
    data_cfg = yaml.safe_load(f)
data_cfg
# Out:
# {'train': '../train/images',
#  'val': '../valid/images',
#  'test': '../test/images',
#  'nc': 2,
#  'names': ['helm', 'no-helm'],
#  'roboflow': {'workspace': 'salo7ty',
#   'project': 'safety-helmet-q3b8o-zlhhn',
#   'version': 1,
#   'license': 'CC BY 4.0',
#   'url': 'https://universe.roboflow.com/salo7ty/safety-helmet-q3b8o-zlhhn/dataset/1'}}

# %%
class_names = data_cfg["names"]
n_classes = len(class_names)
print("Classes:", class_names)
# Out:
# Classes: ['helm', 'no-helm']

# %%
print("Classes:", n_classes)
# Out:
# Classes: 2
